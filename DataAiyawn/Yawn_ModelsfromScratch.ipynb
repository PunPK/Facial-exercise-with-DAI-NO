# %% [markdown]
# <a href="https://colab.research.google.com/github/PunPK/AI_FallingAsleepDriving/blob/main/Yawn_ModelsfromScratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Strat

# %%
# !pip install -Uqq fastbook
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 39.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 134.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 38.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 26.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 18.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 78.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 25.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 52.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.6 MB/s eta 0:00:00

# %%
import fastbook

# %%
from fastbook import *

# %%
import os
import os.path as op
import shutil
from glob import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split

# %%
from torch import nn

from fastai.callback.hook import summary
from fastai.callback.schedule import fit_one_cycle, lr_find 
from fastai.callback.progress import ProgressCallback

from fastai.data.core import Datasets, DataLoaders, show_at
from fastai.data.external import untar_data, URLs
from fastai.data.transforms import Categorize, GrandparentSplitter, parent_label, ToTensor, IntToFloatTensor, Normalize

from fastai.layers import Flatten
from fastai.learner import Learner

from fastai.metrics import accuracy, CrossEntropyLossFlat

from fastai.vision.augment import CropPad, RandomCrop, PadMode
from fastai.vision.core import PILImageBW
from fastai.vision.utils import get_image_files

# %% [markdown]
# # Working with the data

# %%
get_image_files("/content/drive/MyDrive/DataAiyawn/")
# Out:
# (#4190) [Path('/content/drive/MyDrive/DataAiyawn/yawn/2131.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2177.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/215.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2149.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2190.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2271.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2187.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2163.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2142.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2189.jpg')...]

# %%
get_image_files("/content/drive/MyDrive/DataAiyawn/yawn/")
# Out:
# (#2113) [Path('/content/drive/MyDrive/DataAiyawn/yawn/2131.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2177.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/215.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2149.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2190.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2271.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2187.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2163.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2142.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2189.jpg')...]

# %%
get_image_files("/content/drive/MyDrive/DataAiyawn/no yawn/")
# Out:
# (#2077) [Path('/content/drive/MyDrive/DataAiyawn/no yawn/3829.jpg'),Path('/content/drive/MyDrive/DataAiyawn/no yawn/4060.jpg'),Path('/content/drive/MyDrive/DataAiyawn/no yawn/4059.jpg'),Path('/content/drive/MyDrive/DataAiyawn/no yawn/3728.jpg'),Path('/content/drive/MyDrive/DataAiyawn/no yawn/4089.jpg'),Path('/content/drive/MyDrive/DataAiyawn/no yawn/4056.jpg'),Path('/content/drive/MyDrive/DataAiyawn/no yawn/3738.jpg'),Path('/content/drive/MyDrive/DataAiyawn/no yawn/3809.jpg'),Path('/content/drive/MyDrive/DataAiyawn/no yawn/3744.jpg'),Path('/content/drive/MyDrive/DataAiyawn/no yawn/3726.jpg')...]

# %%
items = get_image_files("/content/drive/MyDrive/DataAiyawn/")
items
# Out:
# (#4190) [Path('/content/drive/MyDrive/DataAiyawn/yawn/2131.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2177.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/215.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2149.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2190.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2271.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2187.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2163.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2142.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2189.jpg')...]

# %%
items[0]
# Out:
# Path('/content/drive/MyDrive/DataAiyawn/yawn/2131.jpg')

# %%
parent_label("/content/drive/MyDrive/DataAiyawn")
# Out:
# 'MyDrive'

# %%
im = PILImage.create(items[0])
im.show()
# Out:
# <Axes: >

# %%
splits = RandomSplitter(valid_pct=0.2, seed=42)

# %%
items[:3]
# Out:
# (#3) [Path('/content/drive/MyDrive/DataAiyawn/yawn/2131.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/2177.jpg'),Path('/content/drive/MyDrive/DataAiyawn/yawn/215.jpg')]

# %%
splits = splits(items)

# %%
splits[0][:5], splits[1][:5]
# Out:
# ((#5) [257,3817,2492,4098,1578], (#5) [172,3280,3630,3749,3102])

# %%
dsrc = Datasets(items, tfms=[[PILImage.create], [parent_label, Categorize]], 
                  splits=splits)

# %%
show_at(dsrc.train, 3)
# Out:
# <Axes: title={'center': 'no yawn'}>

# %%
tfms = [ToTensor(), RandomResizedCrop(224, min_scale=0.5) ]
#tfms = [ToTensor(), CropPad(size=34, pad_mode=PadMode.Zeros), RandomCrop(size=28)]
#tfms = [ToTensor(), CropPad(size=224, pad_mode=PadMode.Zeros), RandomCrop(size=224)]

# %%
gpu_tfms = [IntToFloatTensor(), Normalize()]

# %%
dls = dsrc.dataloaders(bs=128, after_item=tfms, after_batch=gpu_tfms)

# %%
dls.show_batch(max_n=8, nrows=2)

# %%
xb, yb = dls.one_batch()

# %%
xb.shape, yb.shape
# Out:
# (torch.Size([128, 3, 224, 224]), torch.Size([128]))

# %%
dls.c
# Out:
# 2

# %% [markdown]
# # The Model

# %%
def conv(ni, nf): return nn.Conv2d(ni, nf, kernel_size=3, stride=2, padding=1)

# %%
def bn(nf): return nn.BatchNorm2d(nf)

# %%
def ReLU(): return nn.ReLU(inplace=False)

# %%
Flatten()
# Out:
# fastai.layers.Flatten(full=False)

# %% [markdown]
# # Making a Model

# %%
model = nn.Sequential(
    conv(3, 8),
    bn(8),
    ReLU(),
    conv(8, 16),
    bn(16),
    ReLU(),
    conv(16,32),
    bn(32),
    ReLU(),
    conv(32, 16),
    bn(16),
    ReLU(),
    conv(16, 10),
    bn(10),
    Flatten()
)

# %%
learn = Learner(dls, model, loss_func=CrossEntropyLossFlat(), metrics=accuracy)

# %%
learn.summary()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Sequential (Input shape: 128 x 3 x 224 x 224)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      128 x 8 x 112 x 112
# Conv2d                                    224        True
# BatchNorm2d                               16         True
# ReLU
# ____________________________________________________________________________
#                      128 x 16 x 56 x 56
# Conv2d                                    1168       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      128 x 32 x 28 x 28
# Conv2d                                    4640       True
# BatchNorm2d                               64         True
# ReLU
# ____________________________________________________________________________
#                      128 x 16 x 14 x 14
# Conv2d                                    4624       True
# BatchNorm2d                               32         True
# ReLU
# ____________________________________________________________________________
#                      128 x 10 x 7 x 7
# Conv2d                                    1450       True
# BatchNorm2d                               20         True
# ____________________________________________________________________________
#                      128 x 490
# Flatten
# ____________________________________________________________________________
#
# Total params: 12,270
# Total trainable params: 12,270
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x7f68a04e8c10>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Callbacks:
#   - TrainEvalCallback
#   - CastToTensor
#   - Recorder
#   - ProgressCallback

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.00363078061491251)

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0020892962347716093)

# %%
learn.fit_one_cycle(4, lr_max=0.0020892962347716093)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.583479</td>
#       <td>5.219145</td>
#       <td>0.482100</td>
#       <td>01:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.085385</td>
#       <td>3.008546</td>
#       <td>0.497613</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.494228</td>
#       <td>2.811354</td>
#       <td>0.497613</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.181988</td>
#       <td>2.779156</td>
#       <td>0.497613</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.007959</td>
#       <td>2.794257</td>
#       <td>0.497613</td>
#       <td>00:38</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Simplify it

# %%
def conv2(ni, nf): return ConvLayer(ni, nf, stride=2)

# %%
net = nn.Sequential(
    conv2(3,8),
    conv2(8,16),
    conv2(16,32),
    conv2(32,16),
    conv2(16,10),
    Flatten()
)

# %%
learn = Learner(dls, net, loss_func=CrossEntropyLossFlat(), metrics=accuracy)

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.005248074419796467)

# %%
learn.fit_one_cycle(4, lr_max=0.005248074419796467)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.280896</td>
#       <td>4.835937</td>
#       <td>0.260143</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.878514</td>
#       <td>2.653405</td>
#       <td>0.497613</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.223463</td>
#       <td>2.419374</td>
#       <td>0.497613</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.847723</td>
#       <td>2.329821</td>
#       <td>0.497613</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.633640</td>
#       <td>2.348047</td>
#       <td>0.497613</td>
#       <td>00:39</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # ResNet (kinda)

# %%
class ResBlock(Module):
  def __init__(self, nf):
    self.conv1 = ConvLayer(nf, nf)
    self.conv2 = ConvLayer(nf, nf)
  
  def forward(self, x): return x + self.conv2(self.conv1(x))

# %%
net = nn.Sequential(
    conv2(3,8),
    ResBlock(8),
    conv2(8,16),
    ResBlock(16),
    conv2(16,32),
    ResBlock(32),
    conv2(32,16),
    ResBlock(16),
    conv2(16,10),
    Flatten()
)

# %%
net
# Out:
# Sequential(
#   (0): ConvLayer(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (1): ResBlock(
#     (conv1): ConvLayer(
#       (0): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv2): ConvLayer(
#       (0): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#   )
#   (2): ConvLayer(
#     (0): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (3): ResBlock(
#     (conv1): ConvLayer(
#       (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv2): ConvLayer(
#       (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#   )
#   (4): ConvLayer(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (5): ResBlock(
#     (conv1): ConvLayer(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv2): ConvLayer(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#   )
#   (6): ConvLayer(
#     (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (7): ResBlock(
#     (conv1): ConvLayer(
#       (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (conv2): ConvLayer(
#       (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#   )
#   (8): ConvLayer(
#     (0): Conv2d(16, 10, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (9): fastai.layers.Flatten(full=False)
# )

# %%
def conv_and_res(ni, nf): return nn.Sequential(conv2(ni, nf), ResBlock(nf))

# %%
net = nn.Sequential(
    conv_and_res(3,8),
    conv_and_res(8,16),
    conv_and_res(16,32),
    conv_and_res(32,16),
    conv2(16,10),
    Flatten()
)

# %%
learn = Learner(dls, net, loss_func=CrossEntropyLossFlat(), metrics=accuracy)

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0030199517495930195)

# %%
learn.fit_one_cycle(20, lr_max=0.0030199517495930195)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.725773</td>
#       <td>5.317436</td>
#       <td>0.062053</td>
#       <td>03:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.349161</td>
#       <td>2.367991</td>
#       <td>0.495227</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.106672</td>
#       <td>1.237648</td>
#       <td>0.613365</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.344294</td>
#       <td>1.067038</td>
#       <td>0.659905</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.812625</td>
#       <td>1.076996</td>
#       <td>0.726730</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.425973</td>
#       <td>0.798399</td>
#       <td>0.767303</td>
#       <td>01:34</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.124354</td>
#       <td>0.584632</td>
#       <td>0.857995</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.902743</td>
#       <td>0.583124</td>
#       <td>0.809069</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.735958</td>
#       <td>0.514530</td>
#       <td>0.847255</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.618024</td>
#       <td>0.400135</td>
#       <td>0.868735</td>
#       <td>01:24</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.528755</td>
#       <td>0.389893</td>
#       <td>0.885442</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.458686</td>
#       <td>0.372105</td>
#       <td>0.893795</td>
#       <td>01:40</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.417280</td>
#       <td>0.259097</td>
#       <td>0.920048</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.371704</td>
#       <td>0.261882</td>
#       <td>0.915274</td>
#       <td>01:24</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.344049</td>
#       <td>0.249854</td>
#       <td>0.931981</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.316192</td>
#       <td>0.235404</td>
#       <td>0.933174</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.288905</td>
#       <td>0.233938</td>
#       <td>0.935561</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.270166</td>
#       <td>0.218074</td>
#       <td>0.942721</td>
#       <td>01:35</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.262347</td>
#       <td>0.215870</td>
#       <td>0.945107</td>
#       <td>01:24</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.255150</td>
#       <td>0.214681</td>
#       <td>0.947494</td>
#       <td>01:24</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.print_classification_report()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#               precision    recall  f1-score   support
#
#      no yawn       0.94      0.95      0.95       417
#         yawn       0.95      0.94      0.95       421
#
#     accuracy                           0.95       838
#    macro avg       0.95      0.95      0.95       838
# weighted avg       0.95      0.95      0.95       838

# %%
interp.most_confused(min_val=5)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# [('yawn', 'no yawn', 24), ('no yawn', 'yawn', 20)]

# %%
learn.show_results(shuffle=True)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.predict("/content/drive/MyDrive/DataAiyawn/yawn/2128.jpg")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('yawn',
#  tensor(1),
#  tensor([1.8828e-04, 9.7710e-01, 9.3917e-05, 5.8159e-05, 4.4429e-05, 4.4429e-05, 4.9404e-05, 6.9777e-05, 5.0727e-05, 4.4429e-05, 4.4429e-05, 5.5420e-05, 7.4414e-05, 4.4429e-05, 6.5224e-05, 4.4429e-05,
#          4.4429e-05, 5.2420e-05, 4.4429e-05, 4.8683e-05, 4.4429e-05, 4.4429e-05, 6.1932e-05, 7.0937e-05, 6.7871e-05, 8.2498e-05, 4.8986e-05, 4.4429e-05, 4.8370e-05, 5.4979e-05, 4.4429e-05, 4.5371e-05,
#          4.9129e-05, 4.6060e-05, 4.7049e-05, 7.8616e-05, 5.9876e-05, 5.2355e-05, 5.0726e-05, 5.7755e-05, 4.4429e-05, 4.6900e-05, 4.9032e-05, 6.0389e-05, 4.4571e-05, 4.9347e-05, 4.4429e-05, 5.0372e-05,
#          4.7631e-05, 4.4429e-05, 6.1041e-05, 4.8084e-05, 5.1910e-05, 4.8571e-05, 4.4429e-05, 4.5334e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05,
#          4.4429e-05, 4.5819e-05, 4.4429e-05, 4.4536e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 6.1847e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.8691e-05,
#          6.9439e-05, 4.5747e-05, 5.1373e-05, 4.4429e-05, 4.4591e-05, 4.4429e-05, 4.9136e-05, 5.0962e-05, 4.7563e-05, 4.4429e-05, 4.8742e-05, 4.4429e-05, 4.4429e-05, 5.4415e-05, 4.7656e-05, 4.4429e-05,
#          5.0614e-05, 5.1911e-05, 4.8830e-05, 4.4429e-05, 4.4429e-05, 4.4652e-05, 4.7583e-05, 4.6916e-05, 4.6370e-05, 4.6659e-05, 4.6278e-05, 4.4557e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.6771e-05,
#          4.4991e-05, 4.6837e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 5.0429e-05, 5.0325e-05, 5.0114e-05, 4.4429e-05, 5.0676e-05,
#          4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.9917e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05,
#          4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05, 4.6486e-05, 4.7837e-05, 4.4429e-05, 4.4429e-05,
#          4.4429e-05, 4.4429e-05, 4.4429e-05, 4.9423e-05, 4.4429e-05, 4.5014e-05, 4.8424e-05, 4.4429e-05, 4.4429e-05, 4.4429e-05]))

# %%
learn.export("yawn_ModelsfromScratch.pkl")

# %%
learn.path = Path('')
learn.export(fname= "new_yawn_ModelsfromScratch.pkl")

# %% [markdown]
# # load

# %%
# !pip install -Uqq fastbook

# %%
import cv2 as cv
import cv2 as cv2
import time
import numpy as np
import pandas as pd
# Fast Ai
from fastbook import *
from glob import glob
from pathlib import Path
from sklearn.metrics import precision_recall_fscore_support, accuracy_score, roc_auc_score
import pathlib
import PIL

def conv2(ni, nf): return ConvLayer(ni, nf, stride=2)

class ResBlock(Module):
  def __init__(self, nf):
    self.conv1 = ConvLayer(nf, nf)
    self.conv2 = ConvLayer(nf, nf)
  
  def forward(self, x): return x + self.conv2(self.conv1(x))

def conv_and_res(ni, nf): return nn.Sequential(conv2(ni, nf), ResBlock(nf))

# %%
learn_inf_yawn = load_learner('/content/yawn_ModelsfromScratch.pkl')
